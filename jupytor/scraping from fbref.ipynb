# %%
pip install soccerdata
# Out:
# ...
#   Created wheel for undetected-chromedriver: filename=undetected_chromedriver-3.4.6-py3-none-any.whl size=44486 sha256=1bd829e0da2c809f13ef5590504bbf9f249af99cbe674340b4cc6f938a52de37
#   Stored in directory: c:\users\dev\appdata\local\pip\cache\wheels\fb\00\24\55c9aeff603d85c62f5c3c5b005bccc1908c47027b8280c35f
# Successfully built undetected-chromedriver
# ...
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.7.2
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# spyder 4.1.5 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.1.5 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# ...

# %%
import soccerdata as sd
# Out:
# [03/31/23 15:45:19] INFO     No custom team name replacements found. You can configure these in       ]8;id=329010;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=650028;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\_config.py#85\85]8;;\
#                              C:\Users\dev\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=554537;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=262975;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\_config.py#159\159]8;;\
#                              C:\Users\dev\soccerdata\config\league_dict.json.

# %%
fbref = sd.FBref(leagues="ENG-Premier League", seasons=2021)
print(fbref.__doc__)
# Out:
# [03/31/23 15:54:06] INFO     Saving cached data to C:\Users\dev\soccerdata\data\FBref                 ]8;id=673917;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=456378;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\_common.py#89\89]8;;\
# C:\Users\dev\anaconda3\lib\site-packages\soccerdata\_common.py:462: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg)
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
# ...

# %%
team = fbref.read_team_season_stats(stat_type='standard')

# %%
team.head(20)
# Out:
#                                           # Pl Playing Time               \
#                                                          MP Starts   Min
# league             season team
# ENG-Premier League 2021   Arsenal            3           38     38  3417
#                           Aston Villa        1           38     38  3420
#                           Brighton           2           38     38  3420
#                           Burnley            3           38     38  3420
#                           Chelsea            3           38     38  3420
#                           Crystal Palace     2           38     38  3420
#                           Everton            3           38     38  3420
#                           Fulham             2           38     38  3420
#                           Leeds United       2           38     38  3420
#                           Leicester City     1           38     38  3420
# ...

# %%
player = fbref.read_player_season_stats(stat_type='standard')

# %%
player.head(25)
# Out:
#                                                             Nation    Pos Age  \
#
# league             season team    player
# ENG-Premier League 2021   Arsenal Ainsley Maitland-Niles       ENG  MF,DF  22
#                                   Alexandre Lacazette          FRA     FW  29
#                                   Bernd Leno                   GER     GK  28
#                                   Bukayo Saka                  ENG  FW,MF  18
#                                   Calum Chambers               ENG     DF  25
#                                   Cédric Soares                POR     DF  28
#                                   Dani Ceballos                ESP     MF  23
#                                   David Luiz                   BRA     DF  33
#                                   Eddie Nketiah                ENG     FW  21
#                                   Emile Smith Rowe             ENG  MF,FW  20
# ...

# %%
schedule = fbref.read_schedule(force_cache=False)

# %%
schedule.head()
# Out:
#                                                                  week  day  \
# league             season game
# ENG-Premier League 2021   2020-09-12 Crystal Palace-Southampton   1.0  Sat
#                           2020-09-12 Fulham-Arsenal               1.0  Sat
#                           2020-09-12 Liverpool-Leeds United       1.0  Sat
#                           2020-09-12 West Ham-Newcastle Utd       1.0  Sat
#                           2020-09-13 Tottenham-Everton            1.0  Sun
#
#                                                                       date  \
# league             season game
# ENG-Premier League 2021   2020-09-12 Crystal Palace-Southampton 2020-09-12
#                           2020-09-12 Fulham-Arsenal             2020-09-12
#                           2020-09-12 Liverpool-Leeds United     2020-09-12
#                           2020-09-12 West Ham-Newcastle Utd     2020-09-12
#                           2020-09-13 Tottenham-Everton          2020-09-13
#
# ...

# %%
lineup = fbref.read_lineup(match_id='fc7f9aa1', force_cache=False)
# Out:
# [03/31/23 16:10:11] INFO     [5/1] Retrieving game with id=fc7f9aa1                                    ]8;id=758352;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\fbref.py\fbref.py]8;;\:]8;id=225572;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\fbref.py#581\581]8;;\

# %%
lineup.head(50)
# Out:
#                                                                                                jersey_number  \
# league             season game                         team              player
# ENG-Premier League 2021   2020-09-13 Tottenham-Everton Tottenham Hotspur Hugo Lloris                       1
#                                                                          Matt Doherty                      2
#                                                                          Toby Alderweireld                 4
#                                                                          Pierre Højbjerg                   5
#                                                                          Son Heung-min                     7
#                                                                          Harry Winks                       8
#                                                                          Harry Kane                       10
# ...

# %%
player_stat = fbref.read_player_match_stats(stat_type='summary', match_id='fc7f9aa1', force_cache=False)
# Out:
# [03/31/23 16:12:18] INFO     [5/1] Retrieving game with id=fc7f9aa1                                    ]8;id=50147;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\fbref.py\fbref.py]8;;\:]8;id=478920;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\fbref.py#679\679]8;;\

# %%
player_stat.head()
# Out:
#                                                                                          #  \
#
# league             season game                         team    player
# ENG-Premier League 2021   2020-09-13 Tottenham-Everton Everton Abdoulaye Doucouré     16.0
#                                                                Allan                   6.0
#                                                                André Gomes            21.0
#                                                                Dominic Calvert-Lewin   9.0
#                                                                Gylfi Sigurðsson       10.0
#
#                                                                                        Nation  \
#
# league             season game                         team    player
# ENG-Premier League 2021   2020-09-13 Tottenham-Everton Everton Abdoulaye Doucouré      ml MLI
# ...

# %%
shots = fbref.read_shot_events(match_id='fc7f9aa1', force_cache=False)
# Out:
# [03/31/23 16:13:45] INFO     [5/1] Retrieving game with id=fc7f9aa1                                    ]8;id=224780;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\fbref.py\fbref.py]8;;\:]8;id=609287;file://C:\Users\dev\anaconda3\lib\site-packages\soccerdata\fbref.py#764\764]8;;\

# %%
shots.head(25).sort_values(by='minute', ascending=True)
# Out:
#                                                                                        minute  \
#
# league             season game                         team      player
# ENG-Premier League 2021   2020-09-13 Tottenham-Everton Tottenham Son Heung-min            3.0
#                                                        Everton   Richarlison             16.0
#                                                                  Yerry Mina              23.0
#                                                        Tottenham Son Heung-min           26.0
#                                                        Everton   James Rodríguez         27.0
#                                                                  Richarlison             31.0
#                                                        Tottenham Dele Alli               33.0
#                                                        Everton   James Rodríguez         37.0
# ...

# %%
shots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 24 entries, ('ENG-Premier League', '2021', '2020-09-13 Tottenham-Everton', 'Everton', 'André Gomes') to ('ENG-Premier League', '2021', '2020-09-13 Tottenham-Everton', 'Tottenham', 'Son Heung-min')
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (minute, )       24 non-null     float64
#  1   (xG, )           24 non-null     float64
#  2   (PSxG, )         9 non-null      float64
#  3   (outcome, )      24 non-null     object
#  4   (distance, )     24 non-null     float64
#  5   (body_part, )    24 non-null     object
#  6   (notes, )        4 non-null      object
#  7   (SCA 1, player)  24 non-null     object
#  8   (SCA 1, event)   24 non-null     object
#  9   (SCA 2, player)  24 non-null     object
#  10  (SCA 2, event)   24 non-null     object
# dtypes: float64(4), object(7)
# memory usage: 3.2+ KB

# %%
# team
# player
# schedule
# lineup
# player_stat
# shots
