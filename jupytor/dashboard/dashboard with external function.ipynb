# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from functions import plot_heatmap

# %%
# creating array

x=np.random.randint(1,101,500)

# %%
x
# Out:
# array([ 52,  34,  75,  71,   1,  51,  11,  93,  39,  36,  75,  43,  80,
#         65,  99,  20,  25,  58,  28,  46,   8,  34,  59,  37,  19,  29,
#         11,  62,  39,  23,  72,  82,  88,  96,  36,  78,  28,  90,  12,
#         15,  11,  59,  85,  33,  67,  26,  40,  17, 100,  52,  96,  87,
#         40,  63,  34,  61,  50,  12,  39,   4,  55,  79,  54,  30,  53,
#         19,  36,  15,  13,  81,  41,  28,   2,  60,  42,  43,  73,  73,
#         36,  80,  38,  32, 100,  26,  81,   2,  75,  14,  97,   8,  80,
#          5,  16,  78,  64,  76,  58,  56,  65,  64,  82,  85,  21,  72,
#         44,   3,  42,  51, 100,  42,  79,  75,  42,  29,  42,  39,  11,
#         86,  91,  17,  56,  21,  82,  57,  84, 100,  42,  65,  67,  59,
#         37,  55,   7,  37,   2,  66,  85,  16,  54,   4,  95,  56,  85,
#         10,   9,  67,  54,  42,  41,  54,  86,  59,  26,  41,  90,  54,
#         13,  49,  28,   5,  24,  54,   5,  87,  52,  88,  79,  43,  45,
#         29,  87,  13,  89,  28,  31,  19,  54,  54,  59,  31,  90,  92,
#         40,  69,  38,  25,  40,  90,  95,  57,  38,  56,  89,  53,  38,
#         13, 100,  59,  81,  29,  72,  63,  81,  61,  87,  27,  59,  72,
#         65,  25,  80,   5,  30,  28,  91,  17,  15,  54,  76,  13,  46,
#         35,  29,  48,  55,  64,   2,   4,   8,  23,  52,  22,  10,  33,
#         62,  75,  23,  70,  18,  65,  47,  33,  98,  28,  40,  61,  50,
#         22,  95,  76,  41,  22,  39,  77,  79,  45,  40,  61,   6,  58,
#         77,  87,  39,  61,  33,  72,  84,  15,  78,  54,  69,  10,  39,
#         43,  95,  49,   1,  78,  69,   6,  17,  73,  63,  99,  96,  99,
#         33,   7,  47,  53,  39,  40,  41,  91,  46,  33,   7,  14,  13,
#         69,  68,  42,  38,  99,  32,  11,  91,  11,  83,   2,  41,  92,
#         37,  34,  96,  32,  42,  83,  54,  34,  22,  68,  56,  23,  87,
#         56,  13,  33,  48,   2,  91,  69,  77,  15,  73,  28,  50,  70,
#         40,  15,  16,  53,  24,  86,  14,  87,   2,  34,  84,  77,  53,
#         86,  92,  36,   5,   2,  66,  94,  97,  30,  52,  17,  64,  44,
#          9,  39,  68,  61,  38,  51,  78,  45,  39,  32,  41,  91,  38,
#         31,  55,  89,  33,  16, 100,   9,  36,  31,  53,  67,  18,  32,
#          9,  10,   2,  61,  30,  18,  76,  30,  64,   2,  75,   8,  73,
#         32,  86,   2,  23,  30,  61,  36,  24,  80,  22,  78,  62,  77,
#         97,  11,  68,  80,   2,  76,  59,  10,  78,  85,  83,  84,  68,
#         32,  75,   2,  87,  49,  39,  40,  42,  79,  13,   6,  11,  17,
#         12,  46,  75,  35,  31,  77,  71,  93,  59,  89,  69,  78,   5,
#         77,  61,  19,  78,  55,  11,   2,  32,  59,  30,  74,  71,  35,
#         19,  93,  84,  12,  73,  60,  35,  71,  99,  34,  83,  83,  50,
#         47,  23,  19,  69,  60,  53,  59,  65,  11,  68,  62,  37,   4,
#         48,  98,  29,  63,  96,  55])

# %%
df = pd.read_csv('E:/mckayjohns/data/europaFinal.csv')

# %%
df
# Out:
#       minute  second             teamId     x     y           period  \
# 0          0     0.0  Manchester United   0.0   0.0        FirstHalf
# 1          0     0.0         Villarreal   0.0   0.0        FirstHalf
# 2          0     0.0  Manchester United  49.9  50.0        FirstHalf
# 3          0     3.0  Manchester United  32.2  58.1        FirstHalf
# 4          0    32.0         Villarreal  34.4   0.0        FirstHalf
# ...      ...     ...                ...   ...   ...              ...
# 2066     134    46.0  Manchester United   0.0   0.0  PenaltyShootout
# 2067       0     0.0         Villarreal   0.0   0.0         PostGame
# 2068       0     0.0  Manchester United   0.0   0.0         PostGame
# 2069       0     0.0  Manchester United   0.0   0.0         PreMatch
# 2070       0     0.0         Villarreal   0.0   0.0         PreMatch
#
#               type       outcome  playerId  endX   endY
# 0            Start    Successful       NaN   NaN    NaN
# 1            Start    Successful       NaN   NaN    NaN
# 2             Pass    Successful      18.0  31.5   59.6
# 3             Pass  Unsuccessful       2.0  69.6  100.0
# 4             Pass    Successful       8.0  36.5    9.5
# ...            ...           ...       ...   ...    ...
# 2066           End    Successful       NaN   NaN    NaN
# 2067           End    Successful       NaN   NaN    NaN
# 2068           End    Successful       NaN   NaN    NaN
# 2069  FormationSet    Successful       NaN   NaN    NaN
# 2070  FormationSet    Successful       NaN   NaN    NaN
#
# [2071 rows x 11 columns]

# %%
fig = plt.figure(figsize=(10,10),constrained_layout = True)

gs = fig.add_gridspec(nrows = 3,ncols = 4)

ax1= fig.add_subplot(gs[0,:2])
ax1.set_title('[0,0]')
boxplot = sns.boxplot(x=x,ax=ax1)


ax3= fig.add_subplot(gs[0,2])
ax3.set_title('[0,2]')
ax3.scatter(1,1)

ax4= fig.add_subplot(gs[0,3])
ax4.set_title('[0,3]')
plot_heatmap(heat_df = df, teamId = 'Manchester United', p_type='Pass', ax=ax4)

ax5= fig.add_subplot(gs[1:,0])
ax5.set_title('[1,0]')

ax6= fig.add_subplot(gs[1,1])
ax6.set_title('[1,1]')

ax7= fig.add_subplot(gs[1,2])
ax7.set_title('[1,2]')

ax8= fig.add_subplot(gs[1,3])
ax8.set_title('[1,3]')
plot_heatmap(heat_df = df, teamId='Villarreal',p_type='Pass', ax=ax8)



ax10= fig.add_subplot(gs[2,1])
ax10.set_title('[2,1]')

ax11= fig.add_subplot(gs[2,2])
ax11.set_title('[2,2]')

ax12= fig.add_subplot(gs[2,3])
ax12.set_title('[2,3]')
ax12.scatter(5,12)
# Out:
# C:\Users\dev\anaconda3\lib\site-packages\seaborn\distributions.py:1181: UserWarning: The following kwargs were not used by contour: 'threshold'
#   cset = contour_func(
# C:\Users\dev\anaconda3\lib\site-packages\seaborn\distributions.py:1181: UserWarning: The following kwargs were not used by contour: 'threshold'
#   cset = contour_func(
