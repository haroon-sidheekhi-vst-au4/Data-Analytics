# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import mplsoccer

# %%
df = pd.read_csv('E:/mckayjohnes/github/valladolidA.csv')

# %%
df
# Out:
#               id  eventId  minute  second      teamId     x     y  period  \
# 0     2248226915        2       0     0.0   Barcelona   0.0   0.0       1
# 1     2248226919        2       0     0.0  Valladolid   0.0   0.0       1
# 2     2248226929        3       0     1.0   Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0   Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0   Barcelona  36.6  56.6       1
# ...          ...      ...     ...     ...         ...   ...   ...     ...
# 1673  2248257153     1030      94     0.0   Barcelona   0.0   0.0       2
# 1674  2248257159      779       0     0.0  Valladolid   0.0   0.0      14
# 1675  2248257147     1031       0     0.0   Barcelona   0.0   0.0      14
# 1676  2248274127        1       0     0.0  Valladolid   0.0   0.0      16
# 1677  2248257151        1       0     0.0   Barcelona   0.0   0.0      16
#
#               type     outcome  playerId  endX  endY
# ...

# %%
dfbarca = df[(df['teamId']=='Barcelona') &(df['type']=='Pass') & (df['outcome']=='Successful')]

# %%
dfbarca
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 2     2248226929        3       0     1.0  Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0  Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 5     2248226973        6       0     5.0  Barcelona  28.3  74.1       1
# 6     2248226975        7       0     8.0  Barcelona  11.2  53.7       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1651  2248256867     1018      93    14.0  Barcelona  76.7  31.8       2
# 1652  2248256869     1019      93    17.0  Barcelona  79.6  24.2       2
# 1653  2248256983     1020      93    18.0  Barcelona  77.1  56.4       2
# 1654  2248256989     1021      93    20.0  Barcelona  68.3  55.2       2
# 1667  2248257081     1027      93    50.0  Barcelona  75.6   4.6       2
#
#       type     outcome  playerId  endX  endY
# 2     Pass  Successful       9.0  43.9  46.9
# ...

# %%
customcmap = matplotlib.colors.LinearSegmentedColormap.from_list('custom cmap',['black','red'])

# %%
pitch = mplsoccer.VerticalPitch(pitch_type='opta',pitch_color='black',line_color='w',line_zorder=2)
fig,ax= pitch.draw(figsize=(8,13))

fig.set_facecolor('black')
pitch.kdeplot(dfbarca['x'],
             dfbarca['y'],
             ax=ax,
             cmap='Reds',
             shade=True,
             n_levels = 20,
             zorder=1)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\mplsoccer\_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# <Axes: >

# %%
pitch = mplsoccer.VerticalPitch(pitch_type='opta',pitch_color='black',line_color='w',line_zorder=2)
fig,ax= pitch.draw(figsize=(8,13))

fig.set_facecolor('black')
pitch.kdeplot(dfbarca['x'],
             dfbarca['y'],
             ax=ax,
             cmap=customcmap,
             shade=True,
             n_levels = 100,
             zorder=1)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\mplsoccer\_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# <Axes: >

# %%
dfbarca21 = df[(df['teamId']=='Barcelona') & (df['outcome']=='Successful') & (df['playerId']==21 )]

# %%
dfbarca21
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 14    2248227079       15       0    40.0  Barcelona  29.8  72.3       1
# 24    2248227217       24       1     4.0  Barcelona  63.1  50.4       1
# 31    2248227491       31       1    43.0  Barcelona  56.4  93.3       1
# 58    2248228717       49       4    43.0  Barcelona  33.3  86.6       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1162  2248252063      742      64    31.0  Barcelona  71.4  64.6       2
# 1179  2248252359      753      66    14.0  Barcelona  72.7  20.6       2
# 1212  2248252601      767      67    32.0  Barcelona   0.0   0.0       2
# 1225  2248252843      777      69    21.0  Barcelona  68.3  63.1       2
# 1243  2248252937      794      70    25.0  Barcelona   0.0   0.0       2
#
#                  type     outcome  playerId  endX  endY
# ...

# %%
pitch = mplsoccer.VerticalPitch(pitch_type='opta',pitch_color='black',line_color='w',line_zorder=2)
fig,ax= pitch.draw(figsize=(8,13))

fig.set_facecolor('black')
pitch.kdeplot(dfbarca21['x'],
             dfbarca21['y'],
             ax=ax,
             cmap=customcmap,
             shade=True,
             n_levels = 20,
             zorder=1)

fig.suptitle(y=0.95,t='Origin of each Passes of Barca.21',color='White',fontsize=24)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\mplsoccer\_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
