# %%
import pandas as pd
df = pd.read_csv('E:/mckayjohns/data/valladolidA.csv')

# %%
df
# Out:
#               id  eventId  minute  second      teamId     x     y  period  \
# 0     2248226915        2       0     0.0   Barcelona   0.0   0.0       1
# 1     2248226919        2       0     0.0  Valladolid   0.0   0.0       1
# 2     2248226929        3       0     1.0   Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0   Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0   Barcelona  36.6  56.6       1
# ...          ...      ...     ...     ...         ...   ...   ...     ...
# 1673  2248257153     1030      94     0.0   Barcelona   0.0   0.0       2
# 1674  2248257159      779       0     0.0  Valladolid   0.0   0.0      14
# 1675  2248257147     1031       0     0.0   Barcelona   0.0   0.0      14
# 1676  2248274127        1       0     0.0  Valladolid   0.0   0.0      16
# 1677  2248257151        1       0     0.0   Barcelona   0.0   0.0      16
#
#               type     outcome  playerId  endX  endY
# ...

# %%
import seaborn as sns

# %%
# details about numerical data
df.describe()
# Out:
#                  id       eventId       minute       second            x  \
# count  1.678000e+03   1678.000000  1678.000000  1674.000000  1678.000000
# mean   2.248245e+09    488.128725    46.264601    29.274194    45.694160
# std    9.370136e+03    598.584714    26.910777    17.657246    25.059002
# min    2.248227e+09      1.000000     0.000000     0.000000     0.000000
# 25%    2.248237e+09    229.250000    24.000000    13.000000    27.600000
# 50%    2.248245e+09    453.000000    44.000000    29.000000    44.550000
# 75%    2.248253e+09    679.750000    71.000000    44.750000    64.875000
# max    2.248274e+09  11616.000000    94.000000    59.000000    99.500000
#
#                  y       period       playerId         endX         endY
# count  1678.000000  1678.000000    1664.000000  1192.000000  1192.000000
# mean     48.577533     1.520858  104095.484976    51.464513    49.542617
# std      28.336290     0.828376  142458.389069    22.779440    28.450266
# ...

# %%
df.head()
# Out:
#            id  eventId  minute  second      teamId     x     y  period   type  \
# 0  2248226915        2       0     0.0   Barcelona   0.0   0.0       1  Start
# 1  2248226919        2       0     0.0  Valladolid   0.0   0.0       1  Start
# 2  2248226929        3       0     1.0   Barcelona  50.0  50.0       1   Pass
# 3  2248226941        4       0     2.0   Barcelona  43.8  46.9       1   Pass
# 4  2248226951        5       0     4.0   Barcelona  36.6  56.6       1   Pass
#
#       outcome  playerId  endX  endY
# 0  Successful       NaN   NaN   NaN
# 1  Successful       NaN   NaN   NaN
# 2  Successful       9.0  43.9  46.9
# 3  Successful       8.0  36.4  56.0
# 4  Successful      21.0  28.5  73.8

# %%
df.tail()
# Out:
#               id  eventId  minute  second      teamId    x    y  period  \
# 1673  2248257153     1030      94     0.0   Barcelona  0.0  0.0       2
# 1674  2248257159      779       0     0.0  Valladolid  0.0  0.0      14
# 1675  2248257147     1031       0     0.0   Barcelona  0.0  0.0      14
# 1676  2248274127        1       0     0.0  Valladolid  0.0  0.0      16
# 1677  2248257151        1       0     0.0   Barcelona  0.0  0.0      16
#
#               type     outcome  playerId  endX  endY
# 1673           End  Successful       NaN   NaN   NaN
# 1674           End  Successful       NaN   NaN   NaN
# 1675           End  Successful       NaN   NaN   NaN
# 1676  FormationSet  Successful       NaN   NaN   NaN
# 1677  FormationSet  Successful       NaN   NaN   NaN

# %%
# know the data types
df.dtypes
# Out:
# id            int64
# eventId       int64
# minute        int64
# second      float64
# teamId       object
# x           float64
# y           float64
# period        int64
# type         object
# outcome      object
# playerId    float64
# endX        float64
# endY        float64
# dtype: object

# %%
# finding out missing data

cols = df.columns
sns.heatmap(df[cols].isnull())
# Out:
# <AxesSubplot:>

# %%
 dropped_rows = df.dropna(subset=['endX','endY'])

# %%
print(dropped_rows['endX'].isnull().sum())
# Out:
# 0

# %%
# Out:
# <AxesSubplot:>

# %%
# dropping columns
df_dropped = df.drop(['endX','endY'],axis=1)

# %%
df_dropped.columns
# Out:
# Index(['id', 'eventId', 'minute', 'second', 'teamId', 'x', 'y', 'period',
#        'type', 'outcome', 'playerId'],
#       dtype='object')

# %%
# filling NaN with values

df.playerId = df.playerId.fillna(0)

# %%
df.playerId.head(25)
# Out:
# 0          0.0
# 1          0.0
# 2          9.0
# 3          8.0
# 4         21.0
# 5         15.0
# 6          1.0
# 7         15.0
# 8     382939.0
# 9          1.0
# 10         8.0
# 11        10.0
# 12         8.0
# 13        10.0
# 14        21.0
# 15         8.0
# 16         4.0
# 17        15.0
# 18        21.0
# 19    106868.0
# 20         8.0
# 21         2.0
# 22        28.0
# 23         8.0
# 24        21.0
# Name: playerId, dtype: float64

# %%
df.describe()
# Out:
#                  id       eventId       minute       second            x  \
# count  1.678000e+03   1678.000000  1678.000000  1674.000000  1678.000000
# mean   2.248245e+09    488.128725    46.264601    29.274194    45.694160
# std    9.370136e+03    598.584714    26.910777    17.657246    25.059002
# min    2.248227e+09      1.000000     0.000000     0.000000     0.000000
# 25%    2.248237e+09    229.250000    24.000000    13.000000    27.600000
# 50%    2.248245e+09    453.000000    44.000000    29.000000    44.550000
# 75%    2.248253e+09    679.750000    71.000000    44.750000    64.875000
# max    2.248274e+09  11616.000000    94.000000    59.000000    99.500000
#
#                  y       period       playerId         endX         endY
# count  1678.000000  1678.000000    1678.000000  1192.000000  1192.000000
# mean     48.577533     1.520858  103226.988677    51.464513    49.542617
# std      28.336290     0.828376  142178.324139    22.779440    28.450266
# ...

# %%
#boxplot for numerical values
sns.boxplot(x=df.eventId)
# Out:
# <AxesSubplot:xlabel='eventId'>

# %%
#remove that outlier

df = df[df['eventId']<2000]

# %%
sns.boxplot(x=df.eventId)
# Out:
# <AxesSubplot:xlabel='eventId'>

# %%
df.describe()
# Out:
#                  id      eventId       minute       second            x  \
# count  1.674000e+03  1674.000000  1674.000000  1674.000000  1674.000000
# mean   2.248245e+09   462.131422    46.265233    29.274194    45.635544
# std    9.369213e+03   274.598636    26.927791    17.657246    25.051262
# min    2.248227e+09     1.000000     0.000000     0.000000     0.000000
# 25%    2.248237e+09   229.000000    24.000000    13.000000    27.525000
# 50%    2.248245e+09   452.000000    44.000000    29.000000    44.450000
# 75%    2.248253e+09   677.750000    71.000000    44.750000    64.775000
# max    2.248274e+09  1031.000000    94.000000    59.000000    99.500000
#
#                  y       period       playerId         endX         endY
# count  1674.000000  1674.000000    1674.000000  1192.000000  1192.000000
# mean     48.533931     1.520908  102583.213262    51.464513    49.542617
# std      28.350398     0.829005  141734.927986    22.779440    28.450266
# ...

# %%
# deleting duplicates
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#                  id      eventId       minute       second            x  \
# count  1.674000e+03  1674.000000  1674.000000  1674.000000  1674.000000
# mean   2.248245e+09   462.131422    46.265233    29.274194    45.635544
# std    9.369213e+03   274.598636    26.927791    17.657246    25.051262
# min    2.248227e+09     1.000000     0.000000     0.000000     0.000000
# 25%    2.248237e+09   229.000000    24.000000    13.000000    27.525000
# 50%    2.248245e+09   452.000000    44.000000    29.000000    44.450000
# 75%    2.248253e+09   677.750000    71.000000    44.750000    64.775000
# max    2.248274e+09  1031.000000    94.000000    59.000000    99.500000
#
#                  y       period       playerId         endX         endY
# count  1674.000000  1674.000000    1674.000000  1192.000000  1192.000000
# mean     48.533931     1.520908  102583.213262    51.464513    49.542617
# std      28.350398     0.829005  141734.927986    22.779440    28.450266
# ...

# %%
#inconsistent data in strings


# lowercase
# split the string
# replace the data
# removing spaces
df.teamId.head()
# Out:
# 0     Barcelona
# 1    Valladolid
# 2     Barcelona
# 3     Barcelona
# 4     Barcelona
# Name: teamId, dtype: object

# %%
# lower
df.teamId = df.teamId.str.lower()

# %%
df.teamId.head()
# Out:
# 0     barcelona
# 1    valladolid
# 2     barcelona
# 3     barcelona
# 4     barcelona
# Name: teamId, dtype: object

# %%
df.head(25)
# Out:
#             id  eventId  minute  second      teamId     x     y  period  \
# 0   2248226915        2       0     0.0   barcelona   0.0   0.0       1
# 1   2248226919        2       0     0.0  valladolid   0.0   0.0       1
# 2   2248226929        3       0     1.0   barcelona  50.0  50.0       1
# 3   2248226941        4       0     2.0   barcelona  43.8  46.9       1
# 4   2248226951        5       0     4.0   barcelona  36.6  56.6       1
# 5   2248226973        6       0     5.0   barcelona  28.3  74.1       1
# 6   2248226975        7       0     8.0   barcelona  11.2  53.7       1
# 7   2248226979        8       0    11.0   barcelona  11.1  85.3       1
# 8   2248226981        3       0    11.0  valladolid  81.6  13.6       1
# 9   2248227027       10       0    29.0   barcelona   3.4  48.2       1
# 10  2248227029       11       0    33.0   barcelona  35.6  39.2       1
# 11  2248227051       12       0    35.0   barcelona  38.5  43.9       1
# ...

# %%
#replacing all digits with empty string
# df.period = df.period.str.replace('\d+','')

df.playerId = df.playerId.replace(21,99)

# %%
df.head(25)
# Out:
#             id  eventId  minute  second      teamId     x     y  period  \
# 0   2248226915        2       0     0.0   barcelona   0.0   0.0       1
# 1   2248226919        2       0     0.0  valladolid   0.0   0.0       1
# 2   2248226929        3       0     1.0   barcelona  50.0  50.0       1
# 3   2248226941        4       0     2.0   barcelona  43.8  46.9       1
# 4   2248226951        5       0     4.0   barcelona  36.6  56.6       1
# 5   2248226973        6       0     5.0   barcelona  28.3  74.1       1
# 6   2248226975        7       0     8.0   barcelona  11.2  53.7       1
# 7   2248226979        8       0    11.0   barcelona  11.1  85.3       1
# 8   2248226981        3       0    11.0  valladolid  81.6  13.6       1
# 9   2248227027       10       0    29.0   barcelona   3.4  48.2       1
# 10  2248227029       11       0    33.0   barcelona  35.6  39.2       1
# 11  2248227051       12       0    35.0   barcelona  38.5  43.9       1
# ...

# %%
#removing white spaces
df.teamId = df.teamId.str.strip()
