# %%
import pandas as pd
import matplotlib as pyplot
import mplsoccer
from mplsoccer import Bumpy
import highlight_text
import numpy as np
from PIL import Image
from io import BytesIO
import requests

# %%
pip install highlight_text
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df =pd.read_csv('E:/mckayjohns/data/La Liga.csv')

# %%
df.head()
# Out:
#               Team  Week 1  Week 2  Week 3  Week 4  Week 5  Week 6  Week 7  \
# 0           Alaves      14      18      19      20      17      19      15
# 1    Athletic Club      16      19      14      15      19      14      16
# 2  Atletico Madrid       4       4       2       5       5       4       3
# 3        Barcelona       1       1       1       1       1       1       5
# 4            Cadiz      18      11      15      10      10       8       7
#
#    Week 8  Week 9  ...  Week 25  Week 26  Week 27  Week 28  Week 29  Week 30  \
# 0      15      15  ...       18       19       18       19       20       19
# 1      13      14  ...       10        8       11        9       10       11
# 2       2       1  ...        1        1        1        1        1        1
# 3       6       5  ...        2        2        2        2        2        3
# 4       7       7  ...       15       14       14       15       13       12
#
#    Week 31  Week 32  Week 33  Week 34
# ...

# %%
df = df.T

# %%
df.columns = df.iloc[0]

# %%
df=df.iloc[1:]

# %%
df.head()
# Out:
# Team   Alaves Athletic Club Atletico Madrid Barcelona Cadiz Celta Vigo Eibar  \
# Week 1     14            16               4         1    18         12    13
# Week 2     18            19               4         1    11          7    14
# Week 3     19            14               2         1    15          8    18
# Week 4     20            15               5         1    10         12    19
# Week 5     17            19               5         1    10         13    14
#
# Team   Elche Getafe Granada Huesca Levante Osasuna Real Betis Real Madrid  \
# Week 1    20     19       6     11      15       5          7           3
# Week 2    20     12       2     17      15       9          3           5
# Week 3    20     11       6     17      10      13          5           3
# Week 4    17      7       4     14      13      16          9           2
# Week 5    18     11       4     15      16      12          6           2
#
# ...

# %%
week = ['week' + str(num) for num in range(1,35)]
week
# Out:
# ['week1',
#  'week2',
#  'week3',
#  'week4',
#  'week5',
#  'week6',
#  'week7',
#  'week8',
#  'week9',
#  'week10',
#  'week11',
#  'week12',
#  'week13',
#  'week14',
#  'week15',
#  'week16',
#  'week17',
#  'week18',
#  'week19',
#  'week20',
#  'week21',
#  'week22',
#  'week23',
#  'week24',
#  'week25',
#  'week26',
#  'week27',
#  'week28',
#  'week29',
#  'week30',
#  'week31',
#  'week32',
#  'week33',
#  'week34']

# %%
highlight_dict = {
    'Atletico Madrid' : 'Red',
    'Real Madrid': 'White',
    'Barcelona':'Blue'
}

# %%
bumpy = Bumpy (
    scatter_color = '#282828',
    line_color = '#252525',
    rotate_xticks=90,
    ticklabel_size=15,
    scatter_primary = 'D',
    show_right = True,
    plot_labels=True,
    alignment_yvalue = 0.1,
    alignment_xvalue = 0.65
)

# %%
fig,ax = bumpy.plot(
    x_list = week,
    y_list = np.linspace(1,20,20).astype(int),
    values = df,
    secondary_alpha = 0.5,
    highlight_dict = highlight_dict,
    figsize = (18,18),
    y_label = 'Posiion',
    ylim = (-0.1,23),
    lw =2.5
)

fig.text(s = 'La Liga till week 34', x = 0.2, y=0.84,
        c='white', size = 24, weight='bold')
highlight_text.fig_text(x=0.2,y=0.82,
                       s='Comparing <Atletico>, <Real Madrid>, & <Barcelona>' ,
                        highlight_textprops = [
                            {'color':'red'},
                            {'color':'white'},
                            {'color':'blue'}
                        ],fontsize=20,color='white')
ax2 = fig.add_axes([0.07,.79,.12,.12])
ax2.axis('off')
img = Image.open('E:/Data-analytics/jupytor/laliga.png')
ax2.imshow(img)
