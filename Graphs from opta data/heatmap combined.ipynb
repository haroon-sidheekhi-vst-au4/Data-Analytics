# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import mplsoccer

# %%
df  =pd.read_excel('E:/Docs/Data/England_Premier-League_2022-2023_Tottenham_vs_Manchester United.xlsx')

# %%
df
# Out:
#       minute  second h_a     x     y          type   outcomeType  \
# 0          0     0.0   a  50.1  49.7          Pass    Successful
# 1          0     2.0   a  36.6  50.0          Pass    Successful
# 2          0     5.0   a  28.8  84.1          Pass    Successful
# 3          0     6.0   a  38.6  93.2         carry    Successful
# 4          0     7.0   a  34.4  93.3          Pass    Successful
# ...      ...     ...  ..   ...   ...           ...           ...
# 1947       2     NaN   a  74.4  36.0  OffsideGiven  Unsuccessful
# 1948       8     NaN   h  75.3  71.1  OffsideGiven  Unsuccessful
# 1949      33     NaN   h  88.5  74.2  OffsideGiven  Unsuccessful
# 1950      75     NaN   a  64.2  63.6  OffsideGiven  Unsuccessful
# 1951      93     NaN   a  88.2  46.9  OffsideGiven  Unsuccessful
#
#            playerName  endX  endY  Setpiece        xT  shirtNo position  \
# 0     Bruno Fernandes  36.8  48.1       0.0 -0.003385        8      AMC
# ...

# %%
df1 = df[(df['team']=='Manchester United') &(df['type']=='Pass') & (df['outcomeType']=='Successful')]

# %%
df1
# Out:
#       minute  second h_a     x     y  type outcomeType       playerName  endX  \
# 0          0     0.0   a  50.1  49.7  Pass  Successful  Bruno Fernandes  36.8
# 1          0     2.0   a  36.6  50.0  Pass  Successful         Casemiro  28.8
# 2          0     5.0   a  28.8  84.1  Pass  Successful      Diogo Dalot  38.6
# 4          0     7.0   a  34.4  93.3  Pass  Successful     Jadon Sancho  25.4
# 5          0    10.0   a  24.9  91.8  Pass  Successful      Diogo Dalot  33.2
# ...      ...     ...  ..   ...   ...   ...         ...              ...   ...
# 1936      93    44.0   a  99.5   0.5  Pass  Successful  Bruno Fernandes  83.5
# 1937      93    45.0   a  83.4  13.5  Pass  Successful      Diogo Dalot  74.4
# 1938      93    46.0   a  73.7  39.2  Pass  Successful             Fred  75.1
# 1940      93    47.0   a  79.1  77.8  Pass  Successful  Marcus Rashford  74.5
# 1941      93    47.0   a  75.1  72.4  Pass  Successful        Luke Shaw  79.9
#
# ...

# %%
pitch = mplsoccer.VerticalPitch(pitch_type='opta',pitch_color='black',line_color='w',line_zorder=2)
fig,ax= pitch.draw(figsize=(8,13))

fig.set_facecolor('black')
pitch.kdeplot(df1['x'],
             df1['y'],
             ax=ax,
             cmap='Reds',
             fill=True,
             n_levels = 20,
             zorder=1)
# Out:
# <Axes: >

# %%
pitch = mplsoccer.VerticalPitch(pitch_type='opta',pitch_color='black',line_color='w',line_zorder=2)
fig,ax= pitch.draw(figsize=(8,13))

customcmap = matplotlib.colors.LinearSegmentedColormap.from_list('custom cmap',['black','red'])

fig.set_facecolor('black')
pitch.kdeplot(df1['x'],
             df1['y'],
             ax=ax,
             cmap=customcmap,
             fill=True,
             n_levels = 100,
             zorder=1)
# Out:
# <Axes: >

# %%
dfplayer8 = df[df['shirtNo']==8 ]

# %%
pitch = mplsoccer.VerticalPitch(pitch_type='opta',pitch_color='black',line_color='w',line_zorder=2)
fig,ax= pitch.draw(figsize=(8,13))

fig.set_facecolor('black')
pitch.kdeplot(dfplayer8['x'],
             dfplayer8['y'],
             ax=ax,
             cmap=customcmap,
             fill=True,
             n_levels = 20,
             zorder=1)

fig.suptitle(y=0.95,t='Heatmap of Bruno Fernandes based on origin of each pass \n Manchester United vs Tottenham EPL | 27-04-2023',color='White',fontsize=16)
plt.show()

# %%
pitch = mplsoccer.VerticalPitch(pitch_type='opta',pitch_color='black',line_color='w',line_zorder=2)
fig, axs = pitch.grid(ncols = 4, nrows = 4, grid_height=0.80, title_height=0.06, axis=False,space=0.05,
                     endnote_height=0.05, title_space=0.03, endnote_space=0.01)
names = df1['playerName'].unique()

for name, ax in zip(names, axs['pitch'].flat[:len(names)]):
    #put player name over the plot
    ax.text(50, -7, name,
            ha='center', va='center', fontsize=10)
    player_df = df1.loc[df1["playerName"] == name]
    pitch.kdeplot(player_df['x'],
             player_df['y'],
             ax=ax,
             cmap=customcmap,
             fill=True,
             n_levels = 20,
             zorder=1)
for ax in axs['pitch'][-1, 18 - len(names):]:
    ax.remove()
    
axs['title'].text(0.5, 0.5, 'Heatmap of Manchester United players against Tottenham hotspur \n English Premier League 2022-23 | 28-04-2023', ha='center', va='center', fontsize=15)
plt.show()
